# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.2

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.2

# %%
df = pd.read_csv("../data/raw/boxing/boxing_matches.csv")

# %%
df.head()
# Out:
#    age_A  age_B  height_A  height_B  reach_A  reach_B  stance_A  stance_B  \
# 0   35.0   27.0     179.0     175.0    178.0    179.0  orthodox  orthodox
# 1   26.0   31.0     175.0     185.0    179.0    185.0  orthodox  orthodox
# 2   28.0   26.0     176.0     175.0      NaN    179.0  orthodox  orthodox
# 3   25.0   29.0     175.0     174.0    179.0    180.0  orthodox  orthodox
# 4   25.0   35.0     175.0     170.0    179.0    170.0  orthodox  orthodox
#
#    weight_A  weight_B  ...  kos_A  kos_B  result  decision  judge1_A  \
# 0     160.0     160.0  ...     33   34.0    draw        SD     110.0
# 1     164.0     164.0  ...     34   32.0   win_A        UD     120.0
# 2     154.0     154.0  ...     13   33.0   win_B        KO       NaN
# 3     155.0     155.0  ...     32   19.0   win_A        KO      47.0
# 4     155.0       NaN  ...     32   33.0   win_A        UD     118.0
#
#    judge1_B  judge2_A  judge2_B judge3_A judge3_B
# 0     118.0     115.0     113.0    114.0    114.0
# ...

# %%
print(df.shape)
df.info()
# Out:
# (387427, 26)
# <class 'pandas.DataFrame'>
# RangeIndex: 387427 entries, 0 to 387426
# Data columns (total 26 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   age_A     352888 non-null  float64
#  1   age_B     257935 non-null  float64
#  2   height_A  249246 non-null  float64
#  3   height_B  134640 non-null  float64
#  4   reach_A   112342 non-null  float64
#  5   reach_B   37873 non-null   float64
#  6   stance_A  231009 non-null  str
#  7   stance_B  231009 non-null  str
#  8   weight_A  135573 non-null  float64
#  9   weight_B  130358 non-null  float64
#  10  won_A     387427 non-null  int64
#  11  won_B     387427 non-null  int64
#  12  lost_A    387427 non-null  int64
#  13  lost_B    387427 non-null  int64
#  14  drawn_A   387427 non-null  int64
#  15  drawn_B   387427 non-null  int64
#  16  kos_A     387427 non-null  int64
#  17  kos_B     387348 non-null  float64
#  18  result    387427 non-null  str
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# reach_B     349554
# judge1_B    335367
# judge1_A    335179
# judge3_B    326404
# judge3_A    326196
# judge2_B    317395
# judge2_A    317056
# reach_A     275085
# weight_B    257069
# height_B    252787
# weight_A    251854
# stance_B    156418
# stance_A    156418
# height_A    138181
# age_B       129492
# age_A        34539
# kos_B           79
# won_A            0
# kos_A            0
# drawn_B          0
# drawn_A          0
# lost_B           0
# won_B            0
# lost_A           0
# result           0
# decision         0
# dtype: int64

# %%
df['result'].value_counts()
# Out:
# result
# win_A    321661
# win_B     40994
# draw      24772
# Name: count, dtype: int64

# %%
df['decision'].value_counts()
# Out:
# decision
# PTS    108070
# TKO     89709
# KO      70940
# UD      62290
# NWS     19369
# SD      11323
# MD       9364
# RTD      9065
# DQ       4831
# TD       2466
# Name: count, dtype: int64

# %%
import pandas as pd
import json

raw = pd.read_csv("../data/raw/boxing/boxing_matches.csv")
raw = raw[raw["result"] != "draw"]

# 14 colonnes : 7 stats × 2 boxeurs
medians_cols = [
    "age_A", "age_B",
    "height_A", "height_B",
    "weight_A", "weight_B",
    "won_A", "won_B",
    "lost_A", "lost_B",
    "drawn_A", "drawn_B",
    "kos_A", "kos_B",
]
medians = {col: float(raw[col].median()) for col in medians_cols}

with open("../models/boxing_medians.json", "w") as f:
    json.dump(medians, f, indent=2)

print(medians)
# Out:
# {'age_A': 24.0, 'age_B': 26.0, 'height_A': 173.0, 'height_B': 173.0, 'weight_A': 140.0, 'weight_B': 140.0, 'won_A': 14.0, 'won_B': 8.0, 'lost_A': 2.0, 'lost_B': 5.0, 'drawn_A': 1.0, 'drawn_B': 1.0, 'kos_A': 6.0, 'kos_B': 3.0}
